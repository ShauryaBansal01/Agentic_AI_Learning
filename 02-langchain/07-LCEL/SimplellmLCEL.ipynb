# %%
### USING GROQ API KEY 

import os
from dotenv import load_dotenv
load_dotenv()

groq_api_key = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
model = ChatGroq(model = "openai/gpt-oss-20b",groq_api_key = groq_api_key)
model
# Out:
# ChatGroq(metadata={'lc_versions': {'langchain-core': '1.6.1'}}, profile={'name': 'GPT OSS 20B', 'release_date': '2025-08-05', 'last_updated': '2026-05-27', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x0000022332199220>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000022332199820>, model_name='openai/gpt-oss-20b', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain_core.messages import HumanMessage , SystemMessage

messages = [
    SystemMessage(content="Translate the following from English to French"),
    HumanMessage(content="Hello, how are you?")
]

res = model.invoke(messages)
res
# Out:
# AIMessage(content='Bonjour, comment ça va?', additional_kwargs={'reasoning_content': 'The user wants translation from English to French. The phrase is "Hello, how are you?" So translation: "Bonjour, comment ça va?" Or "Bonjour, comment allez-vous?" The user didn\'t specify formality. Likely casual: "Bonjour, comment vas-tu?" But the phrase "Hello, how are you?" in French: "Bonjour, comment ça va?" That is common. We\'ll provide that.'}, response_metadata={'token_usage': {'completion_tokens': 99, 'prompt_tokens': 87, 'total_tokens': 186, 'completion_time': 0.100883712, 'completion_tokens_details': {'reasoning_tokens': 84}, 'prompt_time': 0.004744623, 'prompt_tokens_details': None, 'queue_time': 0.043045703, 'total_time': 0.105628335}, 'model_name': 'openai/gpt-oss-20b', 'system_fingerprint': 'fp_c5a89987dc', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a05196-6460-7333-89fd-a79a82be20cb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 87, 'output_tokens': 99, 'total_tokens': 186, 'output_token_details': {'reasoning': 84}})

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
output_parser.invoke(res)
# Out:
# 'Bonjour, comment ça va ?'

# %%
### Using LCEL - chain the components
chain = model | output_parser
chain.invoke(messages)
# Out:
# 'Bonjour, comment allez‑vous ?'

# %%
### Prompt Template 

from langchain_core.prompts import ChatPromptTemplate

generic_template = "Translate the following from English to {language}"
prompt = ChatPromptTemplate.from_messages([
    ("system", generic_template),
    ("user" , "{text}")
])

# %%
# Out:
# ChatPromptValue(messages=[SystemMessage(content='Translate the following from English to Japanese', additional_kwargs={}, response_metadata={}), HumanMessage(content='Hello How are you ?', additional_kwargs={}, response_metadata={})])

# %%
chain = prompt | model | output_parser
chain.invoke({"language":"Japanese","text":"Hello, how are you?"})
# Out:
# 'こんにちは、お元気ですか？'
