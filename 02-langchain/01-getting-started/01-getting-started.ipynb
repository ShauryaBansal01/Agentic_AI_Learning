# %% [markdown]
# ## Getting started With Langchain And Open Al
# In this quickstart we'll see how to:
# Get setup with LangChain, LangSmith and LangServe
# Use the most basic and common components of LangChain: prompt templates, models, and output
# parsers.
# Build a simple application with LangChain
# Trace your application with LangSmith
# Serve your application with LangServe

# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: ipykernel in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from -r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: numpy in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from -r requirements.txt (line 2)) (2.5.1)
# Requirement already satisfied: pandas in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from -r requirements.txt (line 3)) (3.0.3)
# Requirement already satisfied: pydantic in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from -r requirements.txt (line 4)) (2.13.4)
# Collecting langchain (from -r requirements.txt (line 5))
#   Downloading langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (9.14.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (8.9.1)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (1.6.0)
# Requirement already satisfied: packaging>=22 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (26.0)
# Requirement already satisfied: psutil>=5.7 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipykernel->-r requirements.txt (line 1)) (5.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pandas->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pandas->-r requirements.txt (line 3)) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic->-r requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic->-r requirements.txt (line 4)) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic->-r requirements.txt (line 4)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic->-r requirements.txt (line 4)) (0.4.2)
# Collecting langchain-core<2.0.0,>=1.4.9 (from langchain->-r requirements.txt (line 5))
#   Downloading langchain_core-1.5.3-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain->-r requirements.txt (line 5))
#   Downloading langgraph-1.2.10-py3-none-any.whl.metadata (4.9 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading langsmith-0.10.14-py3-none-any.whl.metadata (22 kB)
# Collecting pyyaml<7.0.0,>=5.3.0 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading uuid_utils-0.17.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading xxhash-3.8.1-cp312-cp312-win_amd64.whl.metadata (15 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting httpx>=0.25.2 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl.metadata (43 kB)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Collecting anyio>=3.5.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached anyio-4.14.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting distro>=1.7.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting requests>=2.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting sniffio>=1.1 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Collecting certifi (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Using cached certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting idna (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Using cached idna-3.18-py3-none-any.whl.metadata (6.1 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain->-r requirements.txt (line 5))
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->-r requirements.txt (line 1)) (4.9.4)
# Requirement already satisfied: six>=1.5 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 3)) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Downloading charset_normalizer-3.4.9-cp312-cp312-win_amd64.whl.metadata (42 kB)
# Collecting urllib3<3,>=1.26 (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain->-r requirements.txt (line 5))
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: pure_eval in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->-r requirements.txt (line 1)) (0.2.3)
# Downloading langchain-1.3.14-py3-none-any.whl (139 kB)
# Downloading langchain_core-1.5.3-py3-none-any.whl (561 kB)
#    ---------------------------------------- 0.0/561.7 kB ? eta -:--:--
#    ---------------------------------------- 561.7/561.7 kB 9.7 MB/s  0:00:00
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.2.10-py3-none-any.whl (247 kB)
# Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Downloading langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langsmith-0.10.14-py3-none-any.whl (726 kB)
#    ---------------------------------------- 0.0/726.3 kB ? eta -:--:--
#    ---------------------------------------- 726.3/726.3 kB 7.5 MB/s  0:00:00
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Downloading pyyaml-6.0.3-cp312-cp312-win_amd64.whl (154 kB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Downloading uuid_utils-0.17.0-cp312-cp312-win_amd64.whl (172 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached anyio-4.14.2-py3-none-any.whl (125 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached idna-3.18-py3-none-any.whl (65 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp312-cp312-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.4.9-cp312-cp312-win_amd64.whl (162 kB)
# Using cached urllib3-2.7.0-py3-none-any.whl (131 kB)
# Using cached certifi-2026.7.22-py3-none-any.whl (136 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading xxhash-3.8.1-cp312-cp312-win_amd64.whl (32 kB)
# Downloading zstandard-0.25.0-cp312-cp312-win_amd64.whl (506 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, urllib3, tenacity, sniffio, pyyaml, ormsgpack, orjson, langchain-protocol, jsonpointer, idna, h11, distro, charset_normalizer, certifi, requests, jsonpatch, httpcore, anyio, requests-toolbelt, httpx, langsmith, langchain-core, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    -- -------------------------------------  2/30 [websockets]
#    ---- -----------------------------------  3/30 [uuid-utils]
#    ----- ----------------------------------  4/30 [urllib3]
#    --------- ------------------------------  7/30 [pyyaml]
#    ------------- -------------------------- 10/30 [langchain-protocol]
#    ----------------- ---------------------- 13/30 [h11]
#    -------------------- ------------------- 15/30 [charset_normalizer]
#    ---------------------- ----------------- 17/30 [requests]
#    ------------------------- -------------- 19/30 [httpcore]
#    -------------------------- ------------- 20/30 [anyio]
#    -------------------------- ------------- 20/30 [anyio]
#    ----------------------------- ---------- 22/30 [httpx]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    ------------------------------ --------- 23/30 [langsmith]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    -------------------------------- ------- 24/30 [langchain-core]
#    --------------------------------- ------ 25/30 [langgraph-sdk]
#    --------------------------------- ------ 25/30 [langgraph-sdk]
#    ---------------------------------- ----- 26/30 [langgraph-checkpoint]
#    ------------------------------------ --- 27/30 [langgraph-prebuilt]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    ------------------------------------- -- 28/30 [langgraph]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    -------------------------------------- - 29/30 [langchain]
#    ---------------------------------------- 30/30 [langchain]
#
# Successfully installed anyio-4.14.2 certifi-2026.7.22 charset_normalizer-3.4.9 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.18 jsonpatch-1.33 jsonpointer-3.1.1 langchain-1.3.14 langchain-core-1.5.3 langchain-protocol-0.0.18 langgraph-1.2.10 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.4.2 langsmith-0.10.14 orjson-3.11.9 ormsgpack-1.12.2 pyyaml-6.0.3 requests-2.34.2 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 urllib3-2.7.0 uuid-utils-0.17.0 websockets-15.0.1 xxhash-3.8.1 zstandard-0.25.0

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ['GEMINI_API_KEY'] = os.getenv("GEMINI_API_KEY")
os.environ['LANGSMITH_API_KEY'] = os.getenv("LANGSMITH_API_KEY")
os.environ['LANGSMITH_ENDPOINT'] = os.getenv("LANGSMITH_ENDPOINT")
os.environ["LANGSMITH_TRACING"] = "true"
os.environ["LANGSMITH_PROJECT"] = os.getenv("LANGSMITH_PROJECT")

# %%
## using gemini to do my stuff 
# !pip install langchain langchain-google-genai
# Out:
# Requirement already satisfied: langchain in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (1.3.14)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.3.5-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain) (1.6.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain) (1.2.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.10.14)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (0.17.0)
# Requirement already satisfied: anyio in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.9->langchain) (4.14.2)
# Requirement already satisfied: certifi in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.9->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.4.9->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.33.1)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Using cached filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting google-genai<3.0.0,>=1.65.0 (from langchain-google-genai)
#   Downloading google_genai-2.20.0-py3-none-any.whl.metadata (56 kB)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading google_auth-2.57.0-py3-none-any.whl.metadata (6.0 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting cryptography>=38.0.3 (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\shaur\anaconda3\envs\py312\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.7.0)
# Collecting cffi>=2.0.0 (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached cffi-2.1.1-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached pycparser-3.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai)
#   Using cached pyasn1-0.6.4-py3-none-any.whl.metadata (8.4 kB)
# Downloading langchain_google_genai-4.3.5-py3-none-any.whl (74 kB)
# Using cached filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading google_genai-2.20.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ------------------- -------------------- 0.5/1.1 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 4.3 MB/s  0:00:00
# Downloading google_auth-2.57.0-py3-none-any.whl (259 kB)
# Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/3.8 MB 5.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.8 MB 3.5 MB/s eta 0:00:01
#    ------------------- -------------------- 1.8/3.8 MB 3.5 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 3.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 3.7 MB/s  0:00:01
# Using cached cffi-2.1.1-cp312-cp312-win_amd64.whl (185 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Using cached pyasn1-0.6.4-py3-none-any.whl (84 kB)
# Using cached pycparser-3.0-py3-none-any.whl (48 kB)
# Installing collected packages: filetype, pycparser, pyasn1, pyasn1-modules, cffi, cryptography, google-auth, google-genai, langchain-google-genai
#
#    ---- ----------------------------------- 1/9 [pycparser]
#    -------- ------------------------------- 2/9 [pyasn1]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ------------- -------------------------- 3/9 [pyasn1-modules]
#    ----------------- ---------------------- 4/9 [cffi]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    ---------------------- ----------------- 5/9 [cryptography]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    -------------------------- ------------- 6/9 [google-auth]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ------------------------------- -------- 7/9 [google-genai]
#    ---------------------------------------- 9/9 [langchain-google-genai]
#
# Successfully installed cffi-2.1.1 cryptography-50.0.1 filetype-1.2.0 google-auth-2.57.0 google-genai-2.20.0 langchain-google-genai-4.3.5 pyasn1-0.6.4 pyasn1-modules-0.4.2 pycparser-3.0

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
print(llm)
# Out:
# metadata={'lc_versions': {'langchain-core': '1.6.0', 'langchain': '1.3.14', 'langchain-google-genai': '4.3.5'}} profile={'name': 'Gemini 2.5 Flash', 'release_date': '2025-06-17', 'last_updated': '2025-06-17', 'open_weights': False, 'max_input_tokens': 1048576, 'max_output_tokens': 65536, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': True, 'pdf_inputs': True, 'video_inputs': True, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': True, 'image_url_inputs': True, 'image_tool_message': True, 'tool_choice': True} google_api_key=SecretStr('**********') model='gemini-2.5-flash' client=<google.genai.client.Client object at 0x0000026556AF4410> default_metadata=() model_kwargs={}

# %%
## Input and get response from the llm
result = llm.invoke("What is langchain")
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
print(result.content)
# Out:
# **LangChain is an open-source development framework designed to simplify the creation of applications powered by Large Language Models (LLMs).**
#
# In essence, it acts as a **toolkit or an orchestrator** that helps developers build more complex and capable applications by connecting LLMs with external data sources and computational tools.
#
# Here's a breakdown of what that means and why it's important:
#
# ### Why LangChain? (The Problem It Solves)
#
# While LLMs like GPT-4 or Llama are incredibly powerful at generating text, answering questions, and understanding language, they have limitations:
#
# 1.  **Limited Context:** They only know what they were trained on, which means they don't have access to real-time information, private company data, or specific user context.
# 2.  **No External Actions:** They can't directly interact with the outside world – they can't search the internet, call an API, query a database, or perform calculations.
# 3.  **Lack of Memory:** In a multi-turn conversation, they don't inherently remember previous interactions beyond the immediate prompt.
# 4.  **Complexity of Orchestration:** Building multi-step reasoning processes or complex interactions with LLMs can be difficult and require a lot of custom code.
#
# LangChain addresses these limitations by providing a structured way to combine LLMs with other components, allowing for the creation of much more sophisticated applications.
#
# ### Key Concepts & Components of LangChain
#
# LangChain provides modular abstractions and pre-built components that make it easier to:
#
# 1.  **Models:** Interfaces to various LLM providers (OpenAI, Hugging Face, Anthropic, etc.) and different model types (chat models, text completion models, embedding models).
# 2.  **Prompts:** Tools for managing, optimizing, and generating prompts for LLMs, including prompt templates, input/output parsers, and examples.
# 3.  **Chains:** Sequences of calls to LLMs or other utilities. A chain allows you to combine multiple steps, such as fetching data, summarizing it, and then translating it.
#     *   *Example:* A chain could take a user question, look up relevant documents, pass those documents and the question to an LLM, and then format the LLM's answer.
# 4.  **Retrieval:** Integrations with various data sources (databases, APIs, vector stores like Pinecone, Chroma, FAISS) to fetch relevant information and provide it as context to the LLM. This is crucial for **Retrieval-Augmented Generation (RAG)**.
# 5.  **Agents:** These are dynamic chains where the LLM itself decides which tools to use and in what order, based on the user's input. Agents enable LLMs to perform complex tasks by breaking them down into sub-problems and using tools (like search engines, calculators, code interpreters, or custom APIs) to solve them.
# 6.  **Memory:** Mechanisms to persist state between calls of a chain or agent, allowing for conversational history in chatbots.
# 7.  **Tools:** Pre-built or custom functions that an agent can call to interact with the outside world (e.g., Google Search, a Python REPL, a SQL database query, a custom API call).
#
# ### Common Use Cases for LangChain
#
# *   **Chatbots with Memory and Context:** Building conversational AI that remembers past interactions and can access specific knowledge bases.
# *   **Question Answering over Custom Documents (RAG):** Allowing an LLM to answer questions about your own data (e.g., company reports, PDFs, internal wikis) by retrieving relevant snippets and feeding them to the LLM.
# *   **Autonomous Agents:** Creating AI agents that can perform multi-step tasks by deciding which tools to use (e.g., an agent that researches a topic, summarizes it, and then writes an email).
# *   **Data Extraction and Summarization:** Processing large amounts of text to extract specific information or generate concise summaries.
# *   **Code Generation and Debugging:** Using LLMs to assist in coding tasks, potentially leveraging external tools for testing.
#
# ### In Summary
#
# LangChain is a powerful and flexible framework that empowers developers to move beyond simple LLM prompts and build sophisticated, context-aware, and interactive applications that leverage the full potential of large language models by connecting them to the vast ecosystem of data and tools. It's primarily available in Python and JavaScript/TypeScript.

# %%
### chat prompt template
from langchain_core.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([
    ("system" , "You are an expert AI enginner . Provise me with an answer with examples"),
    ("user" , "{input}")
])
prompt
# Out:
# ChatPromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='You are an expert AI enginner . Provise me with an answer with examples'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['input'], input_types={}, partial_variables={}, template='{input}'), additional_kwargs={})])

# %%
## chain
chain = prompt|llm
res = chain.invoke({"input" : "what is langsmith"})
print(res.content)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# As an AI engineer deeply involved in building and deploying LLM-powered applications, I can tell you that **LangSmith is an indispensable, end-to-end platform for debugging, testing, evaluating, and monitoring Large Language Model (LLM) applications, primarily those built with LangChain, but increasingly supporting other frameworks as well.**
#
# Think of LangSmith as the **observability and MLOps platform specifically designed for the unique challenges of LLM development.** Just as you wouldn't deploy a complex microservice architecture without logging, tracing, and monitoring tools, you shouldn't deploy an LLM application without LangSmith.
#
# ---
#
# ### The Problem LangSmith Solves
#
# Developing with LLMs is inherently challenging due to several factors:
#
# 1.  **Non-Determinism:** LLMs are probabilistic. The same prompt can yield different results.
# 2.  **Black Box Nature:** It's hard to see *why* an LLM application produced a certain output, especially in complex chains involving multiple LLM calls, tool uses, and data retrievals.
# 3.  **Performance & Cost:** LLM calls can be slow and expensive. Optimizing these is crucial.
# 4.  **Quality & Reliability:** Ensuring accuracy, reducing hallucinations, and maintaining consistent quality is a continuous effort.
# 5.  **Iterative Development:** Prompt engineering, chain design, and retrieval strategies are highly iterative. You need data to compare versions.
# 6.  **Production Monitoring:** Once deployed, you need to know if your application is performing as expected, if users are encountering issues, or if underlying models are drifting.
#
# Traditional debugging tools (print statements, IDE debuggers) fall short because they don't provide the holistic, trace-based view needed for complex, multi-step LLM interactions.
#
# ---
#
# ### What LangSmith Is (Core Features)
#
# LangSmith addresses these problems with a suite of features:
#
# 1.  **Traceability & Observability:** At its core, LangSmith captures every step of your LLM application's execution (each LLM call, tool invocation, chain step). It visualizes these "traces" in a waterfall diagram, showing inputs, outputs, intermediate steps, latency, and costs.
# 2.  **Debugging:** With detailed traces, you can pinpoint exactly where an issue occurred. Was it the retriever fetching bad documents? Was the prompt poorly formulated? Did a tool return an error?
# 3.  **Testing & Evaluation:**
#     *   **Dataset Creation:** Curate sets of inputs and expected outputs (or desired properties) to test your application against.
#     *   **Run Comparison:** Easily compare the performance of different versions of your application (e.g., new prompt vs. old prompt, different LLM models) against these datasets.
#     *   **Automated Evaluators:** Use built-in or custom evaluators (which can even be other LLMs!) to score outputs based on metrics like accuracy, relevance, helpfulness, sentiment, etc.
#     *   **Human-in-the-Loop Evaluation:** Allow human reviewers to provide feedback and scores on application runs.
# 4.  **Monitoring:** Once in production, LangSmith provides dashboards to track key metrics like average latency, token usage, cost, error rates, and user feedback. It helps identify regressions or performance dips.
# 5.  **Prompt Management & Versioning:** Experiment with different prompts and track their performance across various runs and datasets.
# 6.  **Dataset Management:** Organize and manage your test and evaluation datasets, allowing for continuous improvement and regression testing.
#
# ---
#
# ### How It Works (Simplified)
#
# You integrate LangSmith into your LangChain (or other LLM framework) code by setting a few environment variables (`LANGCHAIN_TRACING_V2=true`, `LANGCHAIN_API_KEY`, `LANGCHAIN_PROJECT`). When your application runs, LangChain automatically sends detailed execution data to the LangSmith cloud platform, where it's stored, processed, and made available through the LangSmith UI.
#
# ---
#
# ### Examples for an AI Engineer
#
# Let's illustrate with common scenarios:
#
# #### Example 1: Debugging a RAG (Retrieval Augmented Generation) Application
#
# **Scenario:** You've built a RAG application that answers questions based on a knowledge base. Users are complaining that for certain questions, the answers are completely irrelevant or hallucinated.
#
# **Without LangSmith:** You'd be adding `print()` statements everywhere: print the query, print the retrieved documents, print the final prompt sent to the LLM, print the LLM's raw output. This is messy, hard to follow, and doesn't scale.
#
# **With LangSmith:**
# 1.  **Reproduce the issue:** Run the problematic query through your application.
# 2.  **View the Trace:** Go to the LangSmith UI and find the "run" corresponding to that query.
# 3.  **Analyze the Waterfall:** You'll see a visual breakdown:
#     *   **Input Question:** Was the user's query parsed correctly?
#     *   **Retrieval Step:** Did the retriever component return relevant documents? *You might immediately see that the top-ranked documents are completely off-topic.*
#     *   **Prompt Construction:** How was the prompt constructed with the retrieved context?
#     *   **LLM Call:** What was the exact prompt sent to the LLM, and what was its raw output?
# 4.  **Identify the Root Cause:** Based on the trace, you might discover:
#     *   The embedding model isn't performing well for this type of query (bad retrieval).
#     *   The chunking strategy for your documents is flawed.
#     *   The prompt template isn't effectively instructing the LLM to use the context.
# 5.  **Iterate and Fix:** Adjust your retrieval strategy, chunking, or prompt. Run the query again and compare the new trace with the old one to see if the issue is resolved.
#
# **Benefit:** Drastically reduced debugging time, clear identification of bottlenecks or failures in complex chains.
#
# ---
#
# #### Example 2: Evaluating a New Prompt Template for Summarization
#
# **Scenario:** You have a summarization chain, and you've developed a new prompt template you believe will produce higher-quality, more concise summaries. You want to objectively compare it against your existing prompt.
#
# **Without LangSmith:** You'd manually run both prompts on a few examples, eyeball the results, maybe use a custom script to calculate a metric like ROUGE (which is complex to set up). This is subjective and error-prone.
#
# **With LangSmith:**
# 1.  **Create a Dataset:** Upload a CSV or JSON file containing `input_text` and `expected_summary` pairs to LangSmith.
# 2.  **Define Your "App" Versions:** Register your current summarization chain (with the old prompt) and your new chain (with the new prompt) as different "apps" or "versions" within LangSmith.
# 3.  **Run Evaluation:** Tell LangSmith to run both versions of your application against your created dataset.
# 4.  **Apply Evaluators:**
#     *   Use a built-in LangSmith evaluator (e.g., an LLM-based "coherence" evaluator) to score the summaries.
#     *   Integrate a custom evaluator (e.g., your ROUGE calculation script).
#     *   Optionally, send some runs for human review.
# 5.  **Compare Results:** LangSmith will provide a side-by-side comparison of metrics (latency, cost, evaluation scores) for both prompt versions across the entire dataset. You can easily see which prompt performs better on average, or identify specific examples where one fails and the other succeeds.
#
# **Benefit:** Data-driven decision-making for prompt engineering, objective performance comparison, and continuous quality improvement.
#
# ---
#
# #### Example 3: Monitoring a Deployed Customer Support Chatbot
#
# **Scenario:** Your LLM-powered chatbot is live, handling customer queries. You need to ensure it's performing well and catch issues proactively.
#
# **Without LangSmith:** You'd rely on general application logs (which don't understand LLM specifics), user complaints, or manually sampling conversations.
#
# **With LangSmith:**
# 1.  **Integrate Monitoring:** Ensure your deployed chatbot sends all its LLM chain runs to LangSmith.
# 2.  **Dashboard View:** LangSmith's monitoring dashboard shows:
#     *   **Average Latency:** Is the bot responding quickly enough?
#     *   **Token Usage/Cost:** Is it cost-effective? Are there spikes?
#     *   **Error Rates:** Are certain types of queries causing the chain to break?
#     *   **Feedback Scores:** If you've integrated user feedback (e.g., thumbs up/down), you can see trends.
# 3.  **Drill Down:** If you see a spike in errors or latency, you can drill down into the specific runs that caused it, view their traces, and understand the context.
# 4.  **Curate Datasets from Production:** Easily select "bad" or "interesting" production runs from the traces and add them to a new test dataset for future regression testing or fine-tuning.
#
# **Benefit:** Proactive identification of issues, understanding real-world performance, and continuously improving the production application based on actual user interactions.
#
# ---
#
# ### Conclusion
#
# For any AI engineer serious about building robust, reliable, and performant LLM applications, especially with LangChain, **LangSmith is not just a nice-to-have; it's a critical piece of the LLMOps puzzle.** It provides the visibility and tooling necessary to move beyond "it works on my machine" to "it works reliably and optimally in production."
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')

# %%
from langchain_core.output_parsers import StrOutputParser

output_parser = StrOutputParser()
chain = prompt|llm|output_parser
res = chain.invoke({"input" : "what is langsmith"})
print(res)
# Out:
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
# As an expert AI engineer, I can tell you that **LangSmith is a powerful platform developed by LangChain, specifically designed for observability, debugging, testing, and monitoring of Large Language Model (LLM) applications throughout their entire lifecycle.**
#
# Think of it as the MLOps/DevOps platform tailored for the unique challenges of building with LLMs. While traditional software development has well-established tools for these tasks, LLM applications introduce novel complexities due to their non-deterministic nature, prompt engineering, chain orchestration, and reliance on external models. LangSmith addresses these directly.
#
# ---
#
# ### The Problem LangSmith Solves
#
# Building robust, reliable, and performant LLM applications is hard because:
#
# 1.  **Non-Determinism:** LLMs don't always give the same output for the same input, making debugging and testing challenging.
# 2.  **Black Box Nature:** It's often difficult to understand *why* an LLM produced a particular output or why a complex chain failed.
# 3.  **Complex Chains & Agents:** Applications often involve multiple LLM calls, tool usage, retrievers, and custom logic (LangChain chains/agents), creating intricate execution paths that are hard to trace.
# 4.  **Prompt Engineering Iteration:** Optimizing prompts requires extensive experimentation and evaluation.
# 5.  **Cost & Latency:** LLM calls can be expensive and slow; understanding where bottlenecks occur is crucial.
# 6.  **Production Monitoring:** Ensuring consistent performance, catching regressions, and identifying prompt injection attempts in live applications is vital.
# 7.  **Evaluation:** Quantifying the quality of LLM outputs (e.g., factual accuracy, relevance, helpfulness) is subjective and complex.
#
# LangSmith acts as your "flight recorder" and "control tower" for these LLM applications, providing visibility and control.
#
# ---
#
# ### Core Capabilities and Features
#
# LangSmith provides a suite of tools to tackle the challenges above:
#
# 1.  **Observability & Tracing:**
#     *   **Visualizing Execution:** It captures and visualizes every step of an LLM application's execution, from the initial input to the final output, including all intermediate LLM calls, tool invocations, and custom logic.
#     *   **Detailed Logs:** For each step, you can see inputs, outputs, full prompts, token counts, latency, cost, and any errors.
#     *   **Hierarchical View:** For complex LangChain runnables/chains, it shows the nested structure, allowing you to drill down into specific components.
#
# 2.  **Debugging:**
#     *   **Pinpointing Failures:** When an application breaks, LangSmith clearly highlights where the error occurred in the execution trace, allowing you to see the exact state that led to the failure.
#     *   **Reproducibility:** You can re-run specific traces with modified inputs or intermediate steps to test fixes quickly.
#     *   **Intermediate Inspection:** Inspect the inputs and outputs of every single component in your chain, which is invaluable for understanding why an agent chose a certain tool or why a retriever returned irrelevant documents.
#
# 3.  **Testing & Evaluation:**
#     *   **Dataset Management:** Create and manage datasets of inputs and corresponding expected outputs (or "reference answers") for your LLM application.
#     *   **Automated Evaluation:** Run your LLM application against these datasets and automatically evaluate its performance using various metrics. LangSmith supports:
#         *   **LLM-based Evaluators:** Using another LLM to judge the quality of your application's output (e.g., "Is the answer factually correct?", "Is the tone appropriate?").
#         *   **Rule-based Evaluators:** Custom Python functions to check for specific keywords, output formats, or other criteria.
#         *   **Human-in-the-Loop:** Facilitates human review and annotation of traces.
#     *   **Comparison Views:** Easily compare the results of different versions of your application (e.g., different prompt templates, different models, different chain architectures) side-by-side to determine which performs better. This is crucial for A/B testing during development.
#
# 4.  **Monitoring & A/B Testing (Production):**
#     *   **Performance Metrics:** Track key metrics like latency, token usage, cost, and error rates of your LLM application in production.
#     *   **Drift Detection:** Identify if the performance or behavior of your application changes over time, potentially indicating a regression or a change in user input patterns.
#     *   **A/B Testing in Prod:** Deploy multiple versions of your application and route traffic to them, using LangSmith to compare their real-world performance and user satisfaction.
#
# 5.  **Prompt Management & Versioning:**
#     *   Store and version control your prompts, making it easy to iterate and revert to previous versions.
#     *   Experiment with different prompt templates and parameters.
#
# ---
#
# ### How it Works
#
# LangSmith integrates seamlessly with LangChain applications. When you enable LangSmith, your LangChain runnables automatically send execution traces, inputs, outputs, and metadata to the LangSmith platform. For non-LangChain applications, you can use the LangSmith SDK to manually instrument your code.
#
# ---
#
# ### Examples and Use Cases
#
# Let's illustrate with practical scenarios:
#
# 1.  **Debugging a RAG (Retrieval Augmented Generation) Application:**
#     *   **Scenario:** You have a RAG application where a user asks a question, documents are retrieved from a vector database, and an LLM synthesizes an answer based on those documents. A user complains the answer is consistently irrelevant.
#     *   **LangSmith's Role:**
#         1.  **Trace Visualization:** You open LangSmith and find the specific trace for the user's query.
#         2.  **Intermediate Inspection:** You can see the input to the retriever, the documents it *actually* retrieved, and the prompt fed to the final LLM.
#         3.  **Identify Bottleneck:** You notice that the retriever is returning documents that are semantically unrelated to the query. Or perhaps the retrieved documents are relevant, but the final LLM's prompt is poorly structured, causing it to ignore the context.
#         4.  **Iterate & Fix:** You adjust your embedding model, retriever parameters, or the LLM's prompt. Then, you re-run the trace (or a test suite) in LangSmith to verify the fix immediately.
#
# 2.  **Evaluating a Chatbot's Persona Consistency:**
#     *   **Scenario:** You're building a customer service chatbot that needs to maintain a helpful, empathetic, and concise persona. You want to ensure it doesn't become overly verbose or informal.
#     *   **LangSmith's Role:**
#         1.  **Create a Dataset:** You create a dataset in LangSmith with various user queries, and for each query, you define "ideal" responses that match your desired persona.
#         2.  **Automated Evaluation:** You set up an LLM-based evaluator in LangSmith that, for each generated response, asks a "judge LLM" questions like: "Is this response empathetic?", "Is it concise?", "Does it maintain a helpful tone?".
#         3.  **Compare Prompts:** You experiment with two different system prompts for your chatbot. You run both versions against your dataset.
#         4.  **Side-by-Side Comparison:** LangSmith shows you side-by-side results, including the scores from your LLM evaluator. You see that "Prompt A" consistently scores higher on "conciseness" and "empathy" than "Prompt B," leading you to choose Prompt A for deployment.
#
# 3.  **Optimizing Prompt Engineering for Cost and Quality:**
#     *   **Scenario:** You have a summarization chain. You've found a prompt that gives good summaries, but it's very long, leading to high token costs. You want to find a shorter prompt that maintains quality.
#     *   **LangSmith's Role:**
#         1.  **Baseline:** You establish a baseline with your current prompt, evaluating it on a dataset for "summary quality" (e.g., using an LLM evaluator for coherence and completeness) and observing its average token usage and cost in LangSmith.
#         2.  **Experimentation:** You create several shorter prompt variations.
#         3.  **Batch Testing:** You run all these prompt variations against your summarization dataset.
#         4.  **Metric Comparison:** LangSmith provides a dashboard showing the token usage, cost, and "summary quality" scores for each prompt version. You might find a prompt that is 30% cheaper in tokens while only having a marginal (e.g., 2%) drop in quality, which is an acceptable trade-off.
#
# ---
#
# ### Conclusion
#
# LangSmith is an indispensable tool for any serious LLM application developer or team. It bridges the gap between experimental LLM prototypes and production-ready, reliable, and observable AI systems. By providing deep visibility into LLM execution, robust testing capabilities, and continuous monitoring, it significantly accelerates development cycles, improves application quality, and instills confidence in deploying LLM-powered solutions.
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithError: Failed to POST https://api.smith.langchain.com/runs/multipart in LangSmith API. HTTPError('403 Client Error: Forbidden for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Forbidden"}\n')
