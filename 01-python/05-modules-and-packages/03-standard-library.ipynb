# %%
import array 
arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math 
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 9
# apple

# %%
## File and Directory Operations
import os
print(os.getcwd()) # Get current working directory
os.mkdir('test_dir')# Create a new directory
# Out:
# c:\Agentic_AI_Learning\Pyhton

# %%
## high level operations on files and directories
import shutil
shutil.copy('../data/test.txt', '../data/test_copy.txt') # Copy a file
# Out:
# 'test_copy.txt'

# %%
## Data Serialization
import json
data = {'name': 'Alice', 'age': 30}
json_str = json.dumps(data) # Serialize to JSON string
print(json_str)
print(type(json_str))
parsed_data = json.loads(json_str) # Deserialize back to Python object
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Alice", "age": 30}
# <class 'str'>
# {'name': 'Alice', 'age': 30}
# <class 'dict'>

# %%
## csv file operations
import csv
with open('../data/example.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Age'])
    writer.writerow(['Alice', 30])

with open('../data/example.csv', mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Alice', '30']

# %%
## datetime operations
from datetime import datetime, timedelta
now = datetime.now()
print(now)
yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-08 17:19:39.528905
# 2026-07-07 17:19:39.528905

# %%
##time 
import time
print(time.time()) # Current time in seconds since the epoch
time.sleep(1) # Sleep for 1 second
print(time.time()) # Current time after sleep
# Out:
# 1783511433.489855
# 1783511434.49153

# %%
## regular expressions
import re
pattern = r'\d+'
text = 'There are 123 apples .'
matches = re.search(pattern, text)
print(matches.group()) # Output: 123
# Out:
# 123
